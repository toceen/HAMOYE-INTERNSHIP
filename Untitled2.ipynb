# %% [markdown]
# <a href="https://colab.research.google.com/github/toceen/HAMOYE-INTERNSHIP/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/Data_for_UCI.csv")
df.head()
# Out:
#        tau1      tau2      tau3      tau4        p1        p2        p3  \
# 0  2.959060  3.079885  8.381025  9.780754  3.763085 -0.782604 -1.257395
# 1  9.304097  4.902524  3.047541  1.369357  5.067812 -1.940058 -1.872742
# 2  8.971707  8.848428  3.046479  1.214518  3.405158 -1.207456 -1.277210
# 3  0.716415  7.669600  4.486641  2.340563  3.963791 -1.027473 -1.938944
# 4  3.134112  7.608772  4.943759  9.857573  3.525811 -1.125531 -1.845975
#
#          p4        g1        g2        g3        g4      stab     stabf
# 0 -1.723086  0.650456  0.859578  0.887445  0.958034  0.055347  unstable
# 1 -1.255012  0.413441  0.862414  0.562139  0.781760 -0.005957    stable
# 2 -0.920492  0.163041  0.766689  0.839444  0.109853  0.003471  unstable
# 3 -0.997374  0.446209  0.976744  0.929381  0.362718  0.028871  unstable
# 4 -0.554305  0.797110  0.455450  0.656947  0.820923  0.049860  unstable

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tau1    10000 non-null  float64
#  1   tau2    10000 non-null  float64
#  2   tau3    10000 non-null  float64
#  3   tau4    10000 non-null  float64
#  4   p1      10000 non-null  float64
#  5   p2      10000 non-null  float64
#  6   p3      10000 non-null  float64
#  7   p4      10000 non-null  float64
#  8   g1      10000 non-null  float64
#  9   g2      10000 non-null  float64
#  10  g3      10000 non-null  float64
#  11  g4      10000 non-null  float64
#  12  stab    10000 non-null  float64
#  13  stabf   10000 non-null  object
# dtypes: float64(13), object(1)
# memory usage: 1.1+ MB

# %%
from sklearn.model_selection import train_test_split

# Assuming you have your features (X) and labels (y) ready

# Split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split("tau1", "stab", test_size=0.2, random_state=1)

# %%
df.describe()
# Out:
#                tau1          tau2          tau3          tau4            p1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      3.750000
# std        2.742548      2.742549      2.742549      2.742556      0.752160
# min        0.500793      0.500141      0.500788      0.500473      1.582590
# 25%        2.874892      2.875140      2.875522      2.874950      3.218300
# 50%        5.250004      5.249981      5.249979      5.249734      3.751025
# 75%        7.624690      7.624893      7.624948      7.624838      4.282420
# max        9.999469      9.999837      9.999450      9.999443      5.864418
#
#                  p2            p3            p4            g1            g2  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean      -1.250000     -1.250000     -1.250000      0.525000      0.525000
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

plt.figure(figsize=[15,8])
plt.subplot(121)
plt.boxplot([df['tau1'],df['tau2'], df['tau3']])
plt.title('Feature tau1, Feature tau2, Feature tau3')

plt.subplot(122)
plt.boxplot([df['g1'],df['g2']])
plt.title('Feature g1, Feature g2')

plt.show()

# %%
import seaborn as sns
correlations = df.corr()
plt.subplots(figsize=(10,8))
mask = np.zeros_like(correlations)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(correlations, xticklabels=df.columns, yticklabels=df.columns,
            mask=mask,annot=True,linewidths=2, vmin=-1, fmt=".2f")
plt.show()
# Out:
# <ipython-input-22-f589fe512723>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlations = df.corr()

# %%
plt.scatter(df['p2'], df['stab'])
plt.xlabel('p2')
plt.ylabel('stab')
plt.title('Relation between p2 and stab columns')
# Out:
# Text(0.5, 1.0, 'Relation between p2 and stab columns')

# %%
df = df.drop(['p1', 'p2', 'p3', 'p4','stabf'], axis=1)
df.head()
# Out:
#        tau1      tau2      tau3      tau4        g1        g2        g3  \
# 0  2.959060  3.079885  8.381025  9.780754  0.650456  0.859578  0.887445
# 1  9.304097  4.902524  3.047541  1.369357  0.413441  0.862414  0.562139
# 2  8.971707  8.848428  3.046479  1.214518  0.163041  0.766689  0.839444
# 3  0.716415  7.669600  4.486641  2.340563  0.446209  0.976744  0.929381
# 4  3.134112  7.608772  4.943759  9.857573  0.797110  0.455450  0.656947
#
#          g4      stab
# 0  0.958034  0.055347
# 1  0.781760 -0.005957
# 2  0.109853  0.003471
# 3  0.362718  0.028871
# 4  0.820923  0.049860

# %%
df.describe()
# Out:
#                tau1          tau2          tau3          tau4            g1  \
# count  10000.000000  10000.000000  10000.000000  10000.000000  10000.000000
# mean       5.250000      5.250001      5.250004      5.249997      0.525000
# std        2.742548      2.742549      2.742549      2.742556      0.274256
# min        0.500793      0.500141      0.500788      0.500473      0.050009
# 25%        2.874892      2.875140      2.875522      2.874950      0.287521
# 50%        5.250004      5.249981      5.249979      5.249734      0.525009
# 75%        7.624690      7.624893      7.624948      7.624838      0.762435
# max        9.999469      9.999837      9.999450      9.999443      0.999937
#
#                  g2            g3            g4          stab
# count  10000.000000  10000.000000  10000.000000  10000.000000
# mean       0.525000      0.525000      0.525000      0.015731
# std        0.274255      0.274255      0.274255      0.036919
# ...

# %%
import seaborn as sns
correlations = df.corr()
plt.subplots(figsize=(10,8))
mask = np.zeros_like(correlations)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(correlations, xticklabels=df.columns, yticklabels=df.columns,
            mask=mask,annot=True,linewidths=2, vmin=-1, fmt=".2f")
plt.show()

# %%
from sklearn.linear_model import Ridge,Lasso
from sklearn.model_selection import train_test_split
X_data= df.drop(['stab'], axis=1)
y_data = df['stab']
X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, test_size=0.30, random_state=0)

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

pipe = Pipeline([('poly', PolynomialFeatures(degree=2)),
                  ('linear', LinearRegression(normalize=True))])

cv_scores = cross_val_score(pipe, X_train, y_train)
print('Cross-validation scores (5-fold):', cv_scores)
print('Mean cross-validation score (5-fold): {:.3f}'.format(np.mean(cv_scores)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-1e238f0fe88c> in <cell line: 5>()
#       3 from sklearn.model_selection import cross_val_score
#       4
# ----> 5 pipe = Pipeline([('poly', PolynomialFeatures(degree=2)),
#       6                   ('linear', LinearRegression(normalize=True))])
#       7
#
# NameError: name 'PolynomialFeatures' is not defined
