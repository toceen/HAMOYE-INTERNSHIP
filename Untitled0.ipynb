# %% [markdown]
# <a href="https://colab.research.google.com/github/toceen/HAMOYE-INTERNSHIP/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = pd.read_csv("/content/ENB2012_data.xlsx - Φύλλο1.csv")
data
# Out:
#        X1     X2     X3      X4   X5  X6   X7  X8     Y1     Y2
# 0    0.98  514.5  294.0  110.25  7.0   2  0.0   0  15.55  21.33
# 1    0.98  514.5  294.0  110.25  7.0   3  0.0   0  15.55  21.33
# 2    0.98  514.5  294.0  110.25  7.0   4  0.0   0  15.55  21.33
# 3    0.98  514.5  294.0  110.25  7.0   5  0.0   0  15.55  21.33
# 4    0.90  563.5  318.5  122.50  7.0   2  0.0   0  20.84  28.28
# ..    ...    ...    ...     ...  ...  ..  ...  ..    ...    ...
# 763  0.64  784.0  343.0  220.50  3.5   5  0.4   5  17.88  21.40
# 764  0.62  808.5  367.5  220.50  3.5   2  0.4   5  16.54  16.88
# 765  0.62  808.5  367.5  220.50  3.5   3  0.4   5  16.44  17.11
# 766  0.62  808.5  367.5  220.50  3.5   4  0.4   5  16.48  16.61
# 767  0.62  808.5  367.5  220.50  3.5   5  0.4   5  16.64  16.03
#
# [768 rows x 10 columns]

# %%
from sklearn.metrics import r2_score
r2_score = data(Y1, predicted_values)

# Print the R^2 score rounded to 2 decimal places
print(f"R^2 score: {r2:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-8859a3039967> in <cell line: 2>()
#       1 from sklearn.metrics import r2_score
# ----> 2 r2_score = data(Y1, predicted_values)
#       3
#       4 # Print the R^2 score rounded to 2 decimal places
#       5 print(f"R^2 score: {r2:.2f}")
#
# NameError: name 'Y1' is not defined
